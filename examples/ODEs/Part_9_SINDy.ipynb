# %% [markdown]
# # SINDy in Neuromancer
#
# This tutorial demonstrates the use of [sparse identification of nonlinear dynamics (SINDy)](https://arxiv.org/abs/1509.03580) in Neuromancer.
#
# ## SINDy for System Identification
# SINDy is a machine learning model that uses sparse regression techniques to estimate the dynamics that guide time derivatives $\dot{x}_k$ from state variables $x$ at time $k$. SINDy does this by creating a library of candidate functions $\theta$, at which each state variable in $x_k$ is evaluated, and coefficients $\xi$. SINDy then uses linear regression to fit the coefficients in the equation $\dot{x}_k = \theta(x_k)\xi$. SINDy aims to find as few nonzero coefficients as possible while still accurately describing the relationship between $x_k$ and $\dot{x}_k$. With this, it is possible to use the values of $\dot{x}_k$ to predict the trajectory of $x_k$ given some initial condition.
#
# <img src="figs/sindy.jpeg" width=600/>
#
#
# ### References
# [1] [Steven L. Brunton, Joshua L. Proctor, and J. Nathan Kutz. “Discovering governing equations from data by sparse identification of nonlinear
# dynamical systems”.](https://arxiv.org/abs/1509.03580)
#
# [2] [Ricky T. Q. Chen, Yulia Rubanova, Jesse Bettencourt, David Duvenaud, Neural Ordinary Differential Equations, NeurIPS 2018](https://arxiv.org/abs/1806.07366)
#
# [3] [Christopher Rackauckas, Yingbo Ma, Julius Martensen, Collin Warner, Kirill Zubov, Rohit Supekar, Dominic Skinner, Ali Ramadhan, Alan Edelman, Universal Differential Equations for Scientific Machine Learning, arXiv:2001.04385](https://arxiv.org/abs/2001.04385)

# %% [markdown]
# ## NeuroMANCER and Dependencies

# %% [markdown]
# ### Install (Colab only)
# Skip this step when running locally.

# %%
#!pip install "neuromancer[examples] @ git+https://github.com/pnnl/neuromancer.git@master"

# %%
import torch
from neuromancer.psl import plot
from neuromancer import psl
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader

from neuromancer.system import Node, System
from neuromancer.dynamics import integrators, ode, library
from neuromancer.trainer import Trainer
from neuromancer.problem import Problem
from neuromancer.loggers import BasicLogger
from neuromancer.dataset import DictDataset
from neuromancer.constraint import variable
from neuromancer.loss import PenaltyLoss
from neuromancer.modules import blocks

torch.manual_seed(0)

# %% [markdown]
# ## Generate trajectories from ODE system
#
# Consider the [Thomas Attractor](https://en.wikipedia.org/wiki/Thomas%27_cyclically_symmetric_attractor) defined by the [ordinary differential equations](https://en.wikipedia.org/wiki/Ordinary_differential_equation):
#
# $$
#  \frac{dx}{dt} = sin(y) - b x
# $$
# $$
#  \frac{dy}{dt} = sin(z) - b y
# $$
# $$
#  \frac{dz}{dt} = sin(x) - b z
# $$
#
# In this example we only have access to limited measurements of the system states $x$.

# %%
system = psl.systems['ThomasAttractor']
modelSystem = system()
ts = modelSystem.ts
nx = modelSystem.nx
raw = modelSystem.simulate(nsim=1000, ts=ts)
plot.pltOL(Y=raw['Y'])
plot.pltPhase(X=raw['Y'])

# %% [markdown]
# ## Create training data of sampled trajectories
#
# We will obtain a dataset of sampled trajectories of the system dynamics to model:
# $$\hat{X} = [\hat{x}^i_0, ..., \hat{x}^i_{N}], \, \, i \in [1, ..., m]$$
# where $N$ represents the prediction horizon, $m$ represents number of measured trajectories, and $i$ represents an index of the sampled trajectory.

# %%
def get_data(sys, nsim, nsteps, ts, bs):
    """
    :param nsteps: (int) Number of timesteps for each batch of training data
    :param sys: (psl.system)
    :param ts: (float) step size
    :param bs: (int) batch size

    """
    train_sim, dev_sim, test_sim = [sys.simulate(nsim=nsim, ts=ts) for i in range(3)]
    nx = sys.nx
    nbatch = nsim//nsteps
    length = (nsim//nsteps) * nsteps

    trainX = train_sim['X'][:length].reshape(nbatch, nsteps, nx)
    trainX = torch.tensor(trainX, dtype=torch.float32)
    train_data = DictDataset({'X': trainX, 'xn': trainX[:, 0:1, :]}, name='train')
    train_loader = DataLoader(train_data, batch_size=bs,
                              collate_fn=train_data.collate_fn, shuffle=True)

    devX = dev_sim['X'][:length].reshape(nbatch, nsteps, nx)
    devX = torch.tensor(devX, dtype=torch.float32)
    dev_data = DictDataset({'X': devX, 'xn': devX[:, 0:1, :]}, name='dev')
    dev_loader = DataLoader(dev_data, batch_size=bs,
                            collate_fn=dev_data.collate_fn, shuffle=True)

    testX = test_sim['X'][:length].reshape(1, nsim, nx)
    testX = torch.tensor(testX, dtype=torch.float32)
    test_data = {'X': testX, 'xn': testX[:, 0:1, :]}

    return train_loader, dev_loader, test_data

# %%
nsim = 1000   # number of simulation steps in the dataset
nsteps = 10   # number of prediction horizon steps in the loss function
bs = 50     # minibatching batch size
train_loader, dev_loader, test_data = get_data(modelSystem, nsim, nsteps, ts, bs)

# %% [markdown]
# ## Library Construction
#
# Here, we create a library of candidate functions $\theta$. This library is a vector of functions: $$\big[f_0(x_k), f_1(x_k), \ldots, f_n(x_k)]$$ Our library will be evaluated for every data point in our dataset, giving us $\theta(x_k)$. The goal is to discover which linear combinations of functions within our library accurately describe the relationship between $x_k$ and $\dot{x}_k$. Thus, it is imperative that we select a library with ample expressiveness to represent all of the dynamics between our state variables $x_k$ and our derivatives $\dot{x}_k$. In most SINDy use cases, the construction of the library of candidate functions is the most importance choice to make in the system identification process.

# %% [markdown]
# ### Function Library
#
# Neuromancer provides access to a function library class, which when given a list of functions, will store them within a vector, and provides an evaluate function so that the functions can easily be evaluated for all points within our data matrix. To construct any general function library, we will need to provide the candidate functions that can be evaluated over the columns of our data matrix (containted in a `list`), an `int` number of input features, and (optionally) a `list` containing the names of our functions. When evaluating, the library expects the data matrix to be in the form of a `torch.Tensor`. The returned `torch.Tensor` from `FunctionLibrary.evaluate(X)` will have the shape of `(number of time steps in X, number of candidate functions)`.

# %%
candidate_functions = [lambda X: X[:,0]**2, lambda X: X[:,0], lambda X: X[:,2]**2, lambda X: 1, lambda X: torch.sin(X[:,1])]
names = ["x0^2", "x0", "x2^2", "1", "sin(x1)"]

theta = library.FunctionLibrary(candidate_functions, nx, function_names=names)
X = torch.tensor(modelSystem.simulate(nsim=nsim, ts=ts)['X'])

theta_X = theta.evaluate(X)
print(theta)
theta_X
# Out:
# x0^2, x0, x2^2, 1, sin(x1)
# tensor([[ 0.8084,  0.8991,  1.1231,  1.0000, -0.7799],
#         [ 0.6510,  0.8068,  1.2375,  1.0000, -0.7093],
#         [ 0.5239,  0.7238,  1.3409,  1.0000, -0.6308],
#         ...,
#         [ 4.0129,  2.0032,  5.4763,  1.0000,  0.9528],
#         [ 4.2261,  2.0557,  5.6674,  1.0000,  0.9429],
#         [ 4.4362,  2.1062,  5.8464,  1.0000,  0.9334]])

# %% [markdown]
# The plot below shows $\theta(X)$.

# %%
plot.pltOL(Y=theta_X)

# %% [markdown]
# Remember, our goal is to find linear combinations of our candidate functions that transform $x_k$ to $\dot{x}_k$, and use that information to project the trajectory of $x_k$ for some initial condition. For example, we know that $$\frac{dx}{dt} = sin(y) - bx.$$ So we could manually do this with our function library, and propagate these small changes in $x_0$ through time using our initial condition. You'll notice that when plotted, this is the same as the blue line in the original plot of our system. The goal of SINDy is to do this exact thing by using linear regression to find which functions in our library are active, and to find proper values for parameters such as $b$.

# %%
dx_dt = theta_X[:,4] - float(modelSystem.b)*theta_X[:,1]
initial_x = float(modelSystem.x0[0])
x = torch.zeros((theta_X.shape))
x[0] = initial_x
step = 1
while step < theta_X.shape[0]:
    x[step] = x[step-1] + modelSystem.ts*dx_dt[step-1]
    step += 1
plot.pltOL(Y=x)

# %% [markdown]
# ### Fourier Library
#
# We start by constructing a Fourier library, which is based on the idea of the [Fourier series](https://en.wikipedia.org/wiki/Fourier_series). In this example, we know there will be some periodicity in our dynamics, and the Fourier series can expand periodic functions into linear combinations of trigonometric functions. When given the number of input features $n$ and a max frequency $m$, the Fourier library will be constructed with in the form: $$\big[sin(x_0), sin(2x_0), \ldots, sin(mx_0), \ldots, sin(x_n), \ldots, sin(mx_n), cos(x_0), \ldots, cos(mx_0), \ldots, cos(x_n), \ldots, cos(mx_n)]$$
#
# Neuromancer provides the Fourier library as a special case of the more general function library class, which accepts an `int` number of input features and an `int` maximum frequency. The library constructs the functions up to the maximum frequency and names each function so that the user does not have to do so.

# %%
four_lib = library.FourierLibrary(nx, max_freq=1)
print(four_lib)
# Out:
# sin(1*x0), sin(1*x1), sin(1*x2), cos(1*x0), cos(1*x1), cos(1*x2)

# %% [markdown]
# ### Polynomial Functions
#
# In this example, we know that we have additional, non-periodic terms based on our state variables. So, we are going to create polynomial library with a max degree of one. This will create a library of the form:
# $$\big[1, x_0, x_0^1, \ldots, x_0^m, \ldots, x_n^m] $$
#
# Here, our max degree, or $m$ is one, which gives us a fairly simple library.
#
# Next, we can use present a `list` of our two libraries to Neuromancer's `CombinedLibrary` class, which will combine our libraries for us.

# %%
poly_lib = library.PolynomialLibrary(nx, max_degree=1)

theta = library.CombinedLibrary([four_lib, poly_lib])
print(theta)
# Out:
# sin(1*x0), sin(1*x1), sin(1*x2), cos(1*x0), cos(1*x1), cos(1*x2), 1, x0, x1, x2

# %% [markdown]
# ## SINDy system model
#
# Here we construct a SINDy model based on our library: $$\dot{x}_k = \theta(x_k^T)\xi,$$ where $x_k$ is a row within the data matrix and $\xi$ is the corresponding column within the matrix of coefficients.

# %%
torch.manual_seed(0)
fx = ode.SINDy(theta)

# %% [markdown]
# ## Model Integration
#
# Then, we combine this SINDy model with a built-in Neuromancer integrator. This means that when we provide our model with a single data point $x_k$, we can receive an estimation of the next data point $x_{k+1}$, instead of an estimation of the derivative $\dot{x_k}$ at the current time step. This saves us the step of having to actually find the true values of $\dot{x}_k$. Now our model can be represented by the expression: $$x_{k+1} = \text{ODESolve}(\theta(x_k^T)\xi)$$

# %% [markdown]
# It is possible to solve SINDy model forward in time using the  [Adjoint state method](https://en.wikipedia.org/wiki/Adjoint_state_method), as depicted in the graphic below.
#
# <img src="../figs/NODE_backprop.png" width="500">

# %% [markdown]
# In this example, we solve the model by unrolling the operations of the RK4 integrator and using the [backpropagation through time](https://en.wikipedia.org/wiki/Backpropagation_through_time) algorithm. This is similar to how we solve the [Neural ODE](https://arxiv.org/abs/1806.07366) in [this example](https://colab.research.google.com/github/pnnl/neuromancer/blob/master/examples/ODEs/Part_1_NODE.ipynb).

# %% [markdown]
# Note that this implementation of SINDy is essentially a special case of the [universal differential equations](https://arxiv.org/abs/2001.04385) formalism. For use of more general UDEs in Neuromancer, [go here](https://colab.research.google.com/github/pnnl/neuromancer/blob/master/examples/ODEs/Part_3_UDE.ipynb).

# %%
fxRK4 = integrators.RK4(fx, h=ts)
dynamics_model = System([Node(fxRK4, ['xn'], ['xn'])], nsteps=nsteps)

# %% [markdown]
# ## Define system identification loss function terms
#
# Here we define loss function terms to fit the ODE parameters from given time-series data.
#
# **Tracking loss:**
# $$\ell_x = Q_N||x^i_k - \hat{x}^i_k||_2^2$$
# **One-step loss:**
# $$\ell_x = Q_1||x^i_1 - \hat{x}^i_1||_2^2$$

# %%
# %% Constraints + losses:
x = variable("X")
xhat = variable('xn')[:, :-1, :]

# one step loss
onestep_loss = 1.*(xhat[:, 1, :] == x[:, 1, :])^2
onestep_loss.name = "onestep_loss"

# reference tracking loss
reference_loss = ((xhat == x)^2)
reference_loss.name = "ref_loss"

# %% [markdown]
# ## Construct System ID learning problem
#
# Given the training dataset $D$ we want to solve the following problem:
#
# $$
# \begin{align}
# &\underset{\xi}{\text{minimize}}     && \sum_{i=1}^m \Big(Q_1||x^i_1 - \hat{x}^i_1||_2^2 + \sum_{k=1}^{N}  Q_N||x^i_k - \hat{x}^i_k||_2^2   \Big) \\
# &\text{subject to}    && x_{k+1} =  \text{ODESolve}(\theta(x_k^T)\xi) \\
# \end{align}
# $$

# %%
# aggregate list of objective terms and constraints
objectives = [reference_loss, onestep_loss]
constraints = []
# create constrained optimization loss
loss = PenaltyLoss(objectives, constraints)
# construct constrained optimization problem
problem = Problem([dynamics_model], loss)

# %% [markdown]
# ## Solve the problem
#
# We fit each of the unknown SINDy parameters $\xi$ using stochastic gradient descent. In the [original SINDy paper](https://arxiv.org/abs/1509.03580), the authors fit $\xi$ using the sequentially thresholded least squares regression algorithm. This algorithm consists of solving the normal equations for [least squares](https://en.wikipedia.org/wiki/Least_squares) regression to find coefficient values in $\xi$. Then for some threshold $\lambda$, set all values of $\xi$ that are less than $\lambda$ to $0$. This process is repeated until convergence. We use standard stochastic gradient descent based methods, which given proper training, will converge to the same values of $\xi$ as sequentially thresholded least squares.

# %%
optimizer = torch.optim.Adam(problem.parameters(),
                             lr=0.3)
# trainer
trainer = Trainer(
    problem,
    train_loader,
    dev_loader,
    test_data,
    optimizer,
    patience=50,
    warmup=200,
    epochs=1000,
    eval_metric="dev_loss",
    train_metric="train_loss",
    dev_metric="dev_loss",
    test_metric="dev_loss",
)

# %%
# %% train
best_model = trainer.train()
problem.load_state_dict(best_model)
# Out:
# epoch: 0  train_loss: 4.867891311645508
# epoch: 1  train_loss: 0.5221876502037048
# epoch: 2  train_loss: 0.7095785140991211
# epoch: 3  train_loss: 0.8823637962341309
# epoch: 4  train_loss: 0.8960303068161011
# epoch: 5  train_loss: 0.8329777121543884
# epoch: 6  train_loss: 0.7955632209777832
# epoch: 7  train_loss: 0.772553026676178
# epoch: 8  train_loss: 0.7395114898681641
# epoch: 9  train_loss: 0.6995929479598999
# epoch: 10  train_loss: 0.6568268537521362
# epoch: 11  train_loss: 0.6313793063163757
# epoch: 12  train_loss: 0.6206457614898682
# epoch: 13  train_loss: 0.6092313528060913
# epoch: 14  train_loss: 0.5956102609634399
# epoch: 15  train_loss: 0.5846871137619019
# epoch: 16  train_loss: 0.5735121965408325
# epoch: 17  train_loss: 0.5618842840194702
# epoch: 18  train_loss: 0.5497625470161438
# epoch: 19  train_loss: 0.5385044813156128
# epoch: 20  train_loss: 0.5259547233581543
# epoch: 21  train_loss: 0.5100744366645813
# epoch: 22  train_loss: 0.48937106132507324
# epoch: 23  train_loss: 0.49072882533073425
# epoch: 24  train_loss: 0.47961944341659546
# epoch: 25  train_loss: 0.4745785593986511
# epoch: 26  train_loss: 0.4626231789588928
# epoch: 27  train_loss: 0.45147836208343506
# epoch: 28  train_loss: 0.4406750500202179
# epoch: 29  train_loss: 0.43028175830841064
# epoch: 30  train_loss: 0.41850680112838745
# epoch: 31  train_loss: 0.40364959836006165
# epoch: 32  train_loss: 0.3907145857810974
# epoch: 33  train_loss: 0.3780359625816345
# epoch: 34  train_loss: 0.3613269329071045
# epoch: 35  train_loss: 0.3549981713294983
# epoch: 36  train_loss: 0.3462464213371277
# epoch: 37  train_loss: 0.3327873945236206
# epoch: 38  train_loss: 0.3194826543331146
# epoch: 39  train_loss: 0.30794385075569153
# epoch: 40  train_loss: 0.2975429892539978
# epoch: 41  train_loss: 0.2838901877403259
# epoch: 42  train_loss: 0.2707057595252991
# epoch: 43  train_loss: 0.2580961585044861
# epoch: 44  train_loss: 0.24677646160125732
# epoch: 45  train_loss: 0.23242086172103882
# epoch: 46  train_loss: 0.2191762775182724
# epoch: 47  train_loss: 0.20525234937667847
# epoch: 48  train_loss: 0.19131840765476227
# epoch: 49  train_loss: 0.17609447240829468
# epoch: 50  train_loss: 0.16068905591964722
# epoch: 51  train_loss: 0.14408481121063232
# epoch: 52  train_loss: 0.1289878785610199
# epoch: 53  train_loss: 0.11160491406917572
# epoch: 54  train_loss: 0.09759005159139633
# epoch: 55  train_loss: 0.08653264492750168
# epoch: 56  train_loss: 0.07571297883987427
# epoch: 57  train_loss: 0.06698518991470337
# epoch: 58  train_loss: 0.05840730294585228
# epoch: 59  train_loss: 0.05000688135623932
# epoch: 60  train_loss: 0.042333364486694336
# epoch: 61  train_loss: 0.035255879163742065
# epoch: 62  train_loss: 0.029890023171901703
# epoch: 63  train_loss: 0.025253266096115112
# epoch: 64  train_loss: 0.021530957892537117
# epoch: 65  train_loss: 0.018743056803941727
# epoch: 66  train_loss: 0.016534367576241493
# epoch: 67  train_loss: 0.014994392171502113
# epoch: 68  train_loss: 0.013929666951298714
# epoch: 69  train_loss: 0.012966355308890343
# epoch: 70  train_loss: 0.012120898813009262
# epoch: 71  train_loss: 0.011534757912158966
# epoch: 72  train_loss: 0.011207874864339828
# epoch: 73  train_loss: 0.010931190103292465
# epoch: 74  train_loss: 0.010824363678693771
# epoch: 75  train_loss: 0.010675951838493347
# epoch: 76  train_loss: 0.010524832643568516
# epoch: 77  train_loss: 0.010245295241475105
# epoch: 78  train_loss: 0.009972712025046349
# epoch: 79  train_loss: 0.009741043671965599
# epoch: 80  train_loss: 0.00952343363314867
# epoch: 81  train_loss: 0.009305884130299091
# epoch: 82  train_loss: 0.009150763973593712
# epoch: 83  train_loss: 0.008907952345907688
# epoch: 84  train_loss: 0.008670439943671227
# epoch: 85  train_loss: 0.008516614325344563
# epoch: 86  train_loss: 0.008256527595221996
# epoch: 87  train_loss: 0.008105078712105751
# epoch: 88  train_loss: 0.007971723563969135
# epoch: 89  train_loss: 0.007824845612049103
# epoch: 90  train_loss: 0.007695237174630165
# epoch: 91  train_loss: 0.007549326866865158
# epoch: 92  train_loss: 0.0074358112178742886
# epoch: 93  train_loss: 0.0072762127965688705
# epoch: 94  train_loss: 0.007175621576607227
# epoch: 95  train_loss: 0.007048969157040119
# epoch: 96  train_loss: 0.0069587333127856255
# epoch: 97  train_loss: 0.006810316350311041
# epoch: 98  train_loss: 0.006696263328194618
# epoch: 99  train_loss: 0.0065910909324884415
# epoch: 100  train_loss: 0.006558060646057129
# epoch: 101  train_loss: 0.006381627172231674
# epoch: 102  train_loss: 0.00630553625524044
# epoch: 103  train_loss: 0.0062124296091496944
# epoch: 104  train_loss: 0.006098784506320953
# epoch: 105  train_loss: 0.005987240932881832
# epoch: 106  train_loss: 0.005896786227822304
# epoch: 107  train_loss: 0.005806559696793556
# epoch: 108  train_loss: 0.005714090541005135
# epoch: 109  train_loss: 0.005628096871078014
# epoch: 110  train_loss: 0.005513328127563
# epoch: 111  train_loss: 0.005439044442027807
# epoch: 112  train_loss: 0.005394333507865667
# epoch: 113  train_loss: 0.005265798419713974
# epoch: 114  train_loss: 0.005187275819480419
# epoch: 115  train_loss: 0.005159580148756504
# epoch: 116  train_loss: 0.005046106409281492
# epoch: 117  train_loss: 0.004954924341291189
# epoch: 118  train_loss: 0.0048996699042618275
# epoch: 119  train_loss: 0.004806962329894304
# epoch: 120  train_loss: 0.0047224778681993484
# epoch: 121  train_loss: 0.0046705212444067
# epoch: 122  train_loss: 0.004564765375107527
# epoch: 123  train_loss: 0.004519172012805939
# epoch: 124  train_loss: 0.0044729760847985744
# epoch: 125  train_loss: 0.004362818785011768
# epoch: 126  train_loss: 0.004314687103033066
# epoch: 127  train_loss: 0.004254394210875034
# epoch: 128  train_loss: 0.00413940055295825
# epoch: 129  train_loss: 0.004105540458112955
# epoch: 130  train_loss: 0.004022671841084957
# epoch: 131  train_loss: 0.003959103487432003
# epoch: 132  train_loss: 0.0038849408738315105
# epoch: 133  train_loss: 0.0038257543928921223
# epoch: 134  train_loss: 0.003791532013565302
# epoch: 135  train_loss: 0.0037106103263795376
# epoch: 136  train_loss: 0.003679234068840742
# epoch: 137  train_loss: 0.003575553186237812
# epoch: 138  train_loss: 0.0035222196020185947
# epoch: 139  train_loss: 0.003469094866886735
# epoch: 140  train_loss: 0.0034229722805321217
# epoch: 141  train_loss: 0.003352565225213766
# epoch: 142  train_loss: 0.003293008077889681
# epoch: 143  train_loss: 0.003234421368688345
# epoch: 144  train_loss: 0.0031782626174390316
# epoch: 145  train_loss: 0.003134204540401697
# epoch: 146  train_loss: 0.0030888747423887253
# epoch: 147  train_loss: 0.0030366897117346525
# epoch: 148  train_loss: 0.0029526830185204744
# epoch: 149  train_loss: 0.002939202357083559
# epoch: 150  train_loss: 0.0028522848151624203
# epoch: 151  train_loss: 0.002824115799739957
# epoch: 152  train_loss: 0.0027584824711084366
# epoch: 153  train_loss: 0.002708932152017951
# epoch: 154  train_loss: 0.0026825994718819857
# epoch: 155  train_loss: 0.002617164049297571
# epoch: 156  train_loss: 0.002565402537584305
# epoch: 157  train_loss: 0.0025262022390961647
# epoch: 158  train_loss: 0.0024863944854587317
# epoch: 159  train_loss: 0.002426305552944541
# epoch: 160  train_loss: 0.0023784798104315996
# epoch: 161  train_loss: 0.0023297688458114862
# epoch: 162  train_loss: 0.0023010624572634697
# epoch: 163  train_loss: 0.002255100291222334
# epoch: 164  train_loss: 0.0022151293233036995
# epoch: 165  train_loss: 0.002172616543248296
# epoch: 166  train_loss: 0.0021453010849654675
# epoch: 167  train_loss: 0.0020786840468645096
# epoch: 168  train_loss: 0.002053061965852976
# epoch: 169  train_loss: 0.0020136581733822823
# epoch: 170  train_loss: 0.001982075860723853
# epoch: 171  train_loss: 0.0019490380072966218
# epoch: 172  train_loss: 0.0019004934001713991
# epoch: 173  train_loss: 0.0018528500804677606
# epoch: 174  train_loss: 0.0018153863493353128
# epoch: 175  train_loss: 0.0017685461789369583
# epoch: 176  train_loss: 0.001737671671435237
# epoch: 177  train_loss: 0.0017072096234187484
# epoch: 178  train_loss: 0.001665152725763619
# epoch: 179  train_loss: 0.0016368502983823419
# epoch: 180  train_loss: 0.0016050997655838728
# epoch: 181  train_loss: 0.0015689327847212553
# epoch: 182  train_loss: 0.0015462921001017094
# epoch: 183  train_loss: 0.0015121360775083303
# epoch: 184  train_loss: 0.0014730121474713087
# epoch: 185  train_loss: 0.0014418689534068108
# epoch: 186  train_loss: 0.0014110360061749816
# epoch: 187  train_loss: 0.0013817514991387725
# epoch: 188  train_loss: 0.0013441420160233974
# epoch: 189  train_loss: 0.0013274973025545478
# epoch: 190  train_loss: 0.0012896287953481078
# epoch: 191  train_loss: 0.0012565678916871548
# epoch: 192  train_loss: 0.001230563037097454
# epoch: 193  train_loss: 0.0012115875724703074
# epoch: 194  train_loss: 0.0011786496033892035
# epoch: 195  train_loss: 0.0011516503291204572
# epoch: 196  train_loss: 0.001121256034821272
# epoch: 197  train_loss: 0.0010961063671857119
# epoch: 198  train_loss: 0.0010751931695267558
# epoch: 199  train_loss: 0.0010553980246186256
# epoch: 200  train_loss: 0.0010215889196842909
# epoch: 201  train_loss: 0.0010111526353284717
# epoch: 202  train_loss: 0.0009729283628985286
# epoch: 203  train_loss: 0.0009496518177911639
# epoch: 204  train_loss: 0.000931504531763494
# epoch: 205  train_loss: 0.000903779873624444
# epoch: 206  train_loss: 0.0008852740284055471
# epoch: 207  train_loss: 0.0008631155360490084
# epoch: 208  train_loss: 0.0008509443141520023
# epoch: 209  train_loss: 0.0008242763578891754
# epoch: 210  train_loss: 0.0007943167584016919
# epoch: 211  train_loss: 0.0007851696573197842
# epoch: 212  train_loss: 0.0007602684199810028
# epoch: 213  train_loss: 0.0007447621319442987
# epoch: 214  train_loss: 0.0007209625327959657
# epoch: 215  train_loss: 0.0007034045411273837
# epoch: 216  train_loss: 0.000685706443618983
# epoch: 217  train_loss: 0.0006690955488011241
# epoch: 218  train_loss: 0.0006539032328873873
# epoch: 219  train_loss: 0.0006332993507385254
# epoch: 220  train_loss: 0.0006187957478687167
# epoch: 221  train_loss: 0.0006001417059451342
# epoch: 222  train_loss: 0.0005831047310493886
# epoch: 223  train_loss: 0.0005755084566771984
# epoch: 224  train_loss: 0.000551739358343184
# epoch: 225  train_loss: 0.0005406896234489977
# epoch: 226  train_loss: 0.0005243920022621751
# epoch: 227  train_loss: 0.0005163680762052536
# epoch: 228  train_loss: 0.0004942876985296607
# epoch: 229  train_loss: 0.00048320728819817305
# epoch: 230  train_loss: 0.00046854460379108787
# epoch: 231  train_loss: 0.0004623699060175568
# epoch: 232  train_loss: 0.00044489995343610644
# epoch: 233  train_loss: 0.00042940027196891606
# epoch: 234  train_loss: 0.00042625429341569543
# epoch: 235  train_loss: 0.0004061235813423991
# epoch: 236  train_loss: 0.0003977696760557592
# epoch: 237  train_loss: 0.00038570864126086235
# epoch: 238  train_loss: 0.0003747798327822238
# epoch: 239  train_loss: 0.00037110186531208456
# epoch: 240  train_loss: 0.00035278633004054427
# epoch: 241  train_loss: 0.00034062998020090163
# epoch: 242  train_loss: 0.0003341097617521882
# epoch: 243  train_loss: 0.00032515215571038425
# epoch: 244  train_loss: 0.0003092610277235508
# epoch: 245  train_loss: 0.0003094677231274545
# epoch: 246  train_loss: 0.00029304096824489534
# epoch: 247  train_loss: 0.0002894809585995972
# epoch: 248  train_loss: 0.00027333240723237395
# epoch: 249  train_loss: 0.0002702028723433614
# epoch: 250  train_loss: 0.00026713887928053737
# epoch: 251  train_loss: 0.00025533774169161916
# epoch: 252  train_loss: 0.0002507413155399263
# epoch: 253  train_loss: 0.00023764322395436466
# epoch: 254  train_loss: 0.00023257994325831532
# epoch: 255  train_loss: 0.0002218666486442089
# epoch: 256  train_loss: 0.00021854591614101082
# epoch: 257  train_loss: 0.00020402917289175093
# epoch: 258  train_loss: 0.0002055917284451425
# epoch: 259  train_loss: 0.00019354060350451618
# epoch: 260  train_loss: 0.00018832921341527253
# epoch: 261  train_loss: 0.00018240294593852013
# epoch: 262  train_loss: 0.00017707940423861146
# epoch: 263  train_loss: 0.00017034487973432988
# epoch: 264  train_loss: 0.0001660519337747246
# epoch: 265  train_loss: 0.00016078287444543093
# epoch: 266  train_loss: 0.00015433997032232583
# epoch: 267  train_loss: 0.0001492300652898848
# epoch: 268  train_loss: 0.00014209822984412313
# epoch: 269  train_loss: 0.00013926596147939563
# epoch: 270  train_loss: 0.000133348919916898
# epoch: 271  train_loss: 0.00013015947479289025
# epoch: 272  train_loss: 0.00012370171316433698
# epoch: 273  train_loss: 0.00012458431592676789
# epoch: 274  train_loss: 0.00011664844350889325
# epoch: 275  train_loss: 0.00011420988448662683
# epoch: 276  train_loss: 0.00011151177750434726
# epoch: 277  train_loss: 0.00010457902681082487
# epoch: 278  train_loss: 0.00010575006308499724
# epoch: 279  train_loss: 9.877908451016992e-05
# epoch: 280  train_loss: 9.815469820750877e-05
# epoch: 281  train_loss: 9.09942900761962e-05
# epoch: 282  train_loss: 9.074061381397769e-05
# epoch: 283  train_loss: 8.438520308118314e-05
# epoch: 284  train_loss: 8.308151154778898e-05
# epoch: 285  train_loss: 7.836941222194582e-05
# epoch: 286  train_loss: 7.676267705392092e-05
# epoch: 287  train_loss: 7.31006875867024e-05
# epoch: 288  train_loss: 6.982281774980947e-05
# epoch: 289  train_loss: 6.886314076837152e-05
# epoch: 290  train_loss: 6.54344548820518e-05
# epoch: 291  train_loss: 6.252578896237537e-05
# epoch: 292  train_loss: 6.156005838420242e-05
# epoch: 293  train_loss: 5.82290485908743e-05
# epoch: 294  train_loss: 5.681062611984089e-05
# epoch: 295  train_loss: 5.38660679012537e-05
# epoch: 296  train_loss: 5.257336306385696e-05
# epoch: 297  train_loss: 4.994901973986998e-05
# epoch: 298  train_loss: 4.8196103307418525e-05
# epoch: 299  train_loss: 4.64175536762923e-05
# epoch: 300  train_loss: 4.419074684847146e-05
# epoch: 301  train_loss: 4.25534053647425e-05
# epoch: 302  train_loss: 4.098787758266553e-05
# epoch: 303  train_loss: 3.97093353967648e-05
# epoch: 304  train_loss: 3.8057565689086914e-05
# epoch: 305  train_loss: 3.6398443626239896e-05
# epoch: 306  train_loss: 3.440556611167267e-05
# epoch: 307  train_loss: 3.333841959829442e-05
# epoch: 308  train_loss: 3.224430838599801e-05
# epoch: 309  train_loss: 3.097861917922273e-05
# epoch: 310  train_loss: 2.9710507078561932e-05
# epoch: 311  train_loss: 2.8417431167326868e-05
# epoch: 312  train_loss: 2.726018283283338e-05
# epoch: 313  train_loss: 2.6562014681985602e-05
# epoch: 314  train_loss: 2.576555016275961e-05
# epoch: 315  train_loss: 2.4072778614936396e-05
# epoch: 316  train_loss: 2.3165939637692645e-05
# epoch: 317  train_loss: 2.227882396255154e-05
# epoch: 318  train_loss: 2.1972933609504253e-05
# epoch: 319  train_loss: 2.0399407731019892e-05
# epoch: 320  train_loss: 1.9653274648590013e-05
# epoch: 321  train_loss: 1.894897286547348e-05
# epoch: 322  train_loss: 1.8021975847659633e-05
# epoch: 323  train_loss: 1.7384001694153994e-05
# epoch: 324  train_loss: 1.6632620827294886e-05
# epoch: 325  train_loss: 1.60468443937134e-05
# epoch: 326  train_loss: 1.5356936273747124e-05
# epoch: 327  train_loss: 1.4807980733166914e-05
# epoch: 328  train_loss: 1.4296827430371195e-05
# epoch: 329  train_loss: 1.3492272955772933e-05
# epoch: 330  train_loss: 1.2858950867666863e-05
# epoch: 331  train_loss: 1.2459364370442927e-05
# epoch: 332  train_loss: 1.1827882190118544e-05
# epoch: 333  train_loss: 1.1249348972341977e-05
# epoch: 334  train_loss: 1.0825619028764777e-05
# epoch: 335  train_loss: 1.0387256224930752e-05
# epoch: 336  train_loss: 9.968453923647758e-06
# epoch: 337  train_loss: 9.414021405973472e-06
# epoch: 338  train_loss: 8.988418812805321e-06
# epoch: 339  train_loss: 8.639121915621217e-06
# epoch: 340  train_loss: 8.371018338948488e-06
# epoch: 341  train_loss: 7.901760000095237e-06
# epoch: 342  train_loss: 7.589250344608445e-06
# epoch: 343  train_loss: 7.273401024576742e-06
# epoch: 344  train_loss: 6.929924893483985e-06
# epoch: 345  train_loss: 6.7182345446781255e-06
# epoch: 346  train_loss: 6.250315891520586e-06
# epoch: 347  train_loss: 6.193407898535952e-06
# epoch: 348  train_loss: 5.712405709346058e-06
# epoch: 349  train_loss: 5.7129518609144725e-06
# epoch: 350  train_loss: 5.4757606449129526e-06
# epoch: 351  train_loss: 5.237312961980933e-06
# epoch: 352  train_loss: 4.975868705514586e-06
# epoch: 353  train_loss: 4.747504135593772e-06
# epoch: 354  train_loss: 4.441173132363474e-06
# epoch: 355  train_loss: 4.24654263042612e-06
# epoch: 356  train_loss: 4.169135536358226e-06
# epoch: 357  train_loss: 3.854590431728866e-06
# epoch: 358  train_loss: 3.7414574762806296e-06
# epoch: 359  train_loss: 3.5900966395274736e-06
# epoch: 360  train_loss: 3.3756098218873376e-06
# epoch: 361  train_loss: 3.227597517252434e-06
# epoch: 362  train_loss: 3.1285412660508882e-06
# epoch: 363  train_loss: 2.9495033686544048e-06
# epoch: 364  train_loss: 2.8168260541860946e-06
# epoch: 365  train_loss: 2.6219236133329105e-06
# epoch: 366  train_loss: 2.5653566808614414e-06
# epoch: 367  train_loss: 2.418367785139708e-06
# epoch: 368  train_loss: 2.3062532363837818e-06
# epoch: 369  train_loss: 2.1945238586340565e-06
# epoch: 370  train_loss: 2.145467988157179e-06
# epoch: 371  train_loss: 2.032295697063091e-06
# epoch: 372  train_loss: 1.9008652998309117e-06
# epoch: 373  train_loss: 1.8696039205678971e-06
# epoch: 374  train_loss: 1.7109998680098215e-06
# epoch: 375  train_loss: 1.6468848116346635e-06
# epoch: 376  train_loss: 1.56776968651684e-06
# epoch: 377  train_loss: 1.4981108051870251e-06
# epoch: 378  train_loss: 1.4058903161640046e-06
# epoch: 379  train_loss: 1.3709961876884336e-06
# epoch: 380  train_loss: 1.2983999795324053e-06
# epoch: 381  train_loss: 1.313638449573773e-06
# epoch: 382  train_loss: 1.1816670166808763e-06
# epoch: 383  train_loss: 1.1473073300294345e-06
# epoch: 384  train_loss: 1.0824600167325116e-06
# epoch: 385  train_loss: 1.0391853493274539e-06
# epoch: 386  train_loss: 9.96551534626633e-07
# epoch: 387  train_loss: 9.592857850293512e-07
# epoch: 388  train_loss: 9.120726076616847e-07
# epoch: 389  train_loss: 8.589464641772793e-07
# epoch: 390  train_loss: 7.986635637280415e-07
# epoch: 391  train_loss: 7.466614420081896e-07
# epoch: 392  train_loss: 7.137925877032103e-07
# epoch: 393  train_loss: 6.668715286650695e-07
# epoch: 394  train_loss: 6.33495119473082e-07
# epoch: 395  train_loss: 6.108519414738112e-07
# epoch: 396  train_loss: 5.903093551751226e-07
# epoch: 397  train_loss: 5.389138664213533e-07
# epoch: 398  train_loss: 5.163595915291808e-07
# epoch: 399  train_loss: 4.996960569769726e-07
# epoch: 400  train_loss: 4.768537564814324e-07
# epoch: 401  train_loss: 4.3429628249214147e-07
# epoch: 402  train_loss: 4.2176364445367653e-07
# epoch: 403  train_loss: 4.0174086279876065e-07
# epoch: 404  train_loss: 3.8859923279233044e-07
# epoch: 405  train_loss: 3.6709758433062234e-07
# epoch: 406  train_loss: 3.4296766671104706e-07
# epoch: 407  train_loss: 3.2283952577927266e-07
# epoch: 408  train_loss: 3.086278752562066e-07
# epoch: 409  train_loss: 2.9347552299441304e-07
# epoch: 410  train_loss: 2.758111747880321e-07
# epoch: 411  train_loss: 2.6333100322517566e-07
# epoch: 412  train_loss: 2.4807457066344796e-07
# epoch: 413  train_loss: 2.3743075416859938e-07
# epoch: 414  train_loss: 2.2210851113868557e-07
# epoch: 415  train_loss: 2.112125798703346e-07
# epoch: 416  train_loss: 2.0165197156529757e-07
# epoch: 417  train_loss: 1.895572552257363e-07
# epoch: 418  train_loss: 1.7957160025616759e-07
# epoch: 419  train_loss: 1.7250390271783544e-07
# epoch: 420  train_loss: 1.6423686588495912e-07
# epoch: 421  train_loss: 1.5553857224404055e-07
# epoch: 422  train_loss: 1.4434566253385128e-07
# epoch: 423  train_loss: 1.3814798194289324e-07
# epoch: 424  train_loss: 1.3035810297878925e-07
# epoch: 425  train_loss: 1.255557862123169e-07
# epoch: 426  train_loss: 1.1681939326990687e-07
# epoch: 427  train_loss: 1.1129900912010271e-07
# epoch: 428  train_loss: 1.0600959399198473e-07
# epoch: 429  train_loss: 1.0151924101364784e-07
# epoch: 430  train_loss: 9.590435467998759e-08
# epoch: 431  train_loss: 8.958217279086966e-08
# epoch: 432  train_loss: 8.562759035157796e-08
# epoch: 433  train_loss: 8.115431171518139e-08
# epoch: 434  train_loss: 7.61219070000152e-08
# epoch: 435  train_loss: 7.165223792071629e-08
# epoch: 436  train_loss: 6.854034495518135e-08
# epoch: 437  train_loss: 6.449607781178202e-08
# epoch: 438  train_loss: 6.260046347961179e-08
# epoch: 439  train_loss: 5.852352913393588e-08
# epoch: 440  train_loss: 5.5227417306014104e-08
# epoch: 441  train_loss: 5.1682963686516814e-08
# epoch: 442  train_loss: 4.953692922526898e-08
# epoch: 443  train_loss: 4.652021701190279e-08
# epoch: 444  train_loss: 4.3732846677357884e-08
# epoch: 445  train_loss: 4.185727320304977e-08
# epoch: 446  train_loss: 3.91087944251467e-08
# epoch: 447  train_loss: 3.759959099625121e-08
# epoch: 448  train_loss: 3.4689339400983954e-08
# epoch: 449  train_loss: 3.343412657841327e-08
# epoch: 450  train_loss: 3.146560700884038e-08
# epoch: 451  train_loss: 2.9403866008692603e-08
# epoch: 452  train_loss: 2.8016101438765872e-08
# epoch: 453  train_loss: 2.6514683781897475e-08
# epoch: 454  train_loss: 2.423971778853229e-08
# epoch: 455  train_loss: 2.31191013000398e-08
# epoch: 456  train_loss: 2.214600058891847e-08
# epoch: 457  train_loss: 2.1052240839480874e-08
# epoch: 458  train_loss: 1.9837921527710023e-08
# epoch: 459  train_loss: 1.8624177755555138e-08
# epoch: 460  train_loss: 1.764833790218745e-08
# epoch: 461  train_loss: 1.6501209287866914e-08
# epoch: 462  train_loss: 1.5443411882642977e-08
# epoch: 463  train_loss: 1.4890138899659178e-08
# epoch: 464  train_loss: 1.3828595157860946e-08
# epoch: 465  train_loss: 1.2948307315241436e-08
# epoch: 466  train_loss: 1.2036086793898448e-08
# epoch: 467  train_loss: 1.182262465704298e-08
# epoch: 468  train_loss: 1.0639968017756019e-08
# epoch: 469  train_loss: 1.0348885304267696e-08
# epoch: 470  train_loss: 9.500797482075996e-09
# epoch: 471  train_loss: 9.085864505209429e-09
# epoch: 472  train_loss: 8.514891902677846e-09
# epoch: 473  train_loss: 8.143123508830286e-09
# epoch: 474  train_loss: 7.692097625522365e-09
# epoch: 475  train_loss: 7.310615668387754e-09
# epoch: 476  train_loss: 7.093766907217969e-09
# epoch: 477  train_loss: 6.273197961093047e-09
# epoch: 478  train_loss: 6.245096884072154e-09
# epoch: 479  train_loss: 5.751289222644118e-09
# epoch: 480  train_loss: 5.554761095538652e-09
# epoch: 481  train_loss: 4.988370161385092e-09
# epoch: 482  train_loss: 4.996682623215065e-09
# epoch: 483  train_loss: 4.5299328732539834e-09
# epoch: 484  train_loss: 4.388823526824126e-09
# epoch: 485  train_loss: 3.9854355371460315e-09
# epoch: 486  train_loss: 3.748336752096293e-09
# epoch: 487  train_loss: 3.5644771578802192e-09
# epoch: 488  train_loss: 3.280933302818312e-09
# epoch: 489  train_loss: 3.146263916065095e-09
# epoch: 490  train_loss: 2.9507820631380355e-09
# epoch: 491  train_loss: 2.758907324817983e-09
# epoch: 492  train_loss: 2.6254431961802993e-09
# epoch: 493  train_loss: 2.4306614498925683e-09
# epoch: 494  train_loss: 2.2651840403398182e-09
# epoch: 495  train_loss: 2.135146059956128e-09
# epoch: 496  train_loss: 2.0215014107094476e-09
# epoch: 497  train_loss: 1.8547947622238325e-09
# epoch: 498  train_loss: 1.7476048386200205e-09
# epoch: 499  train_loss: 1.6263321800380481e-09
# epoch: 500  train_loss: 1.5336965031309546e-09
# epoch: 501  train_loss: 1.458746456961535e-09
# epoch: 502  train_loss: 1.3625865991073738e-09
# epoch: 503  train_loss: 1.3267408283113014e-09
# epoch: 504  train_loss: 1.2048011477361342e-09
# epoch: 505  train_loss: 1.1189491555541053e-09
# epoch: 506  train_loss: 1.0514757953217213e-09
# epoch: 507  train_loss: 9.944147727480868e-10
# epoch: 508  train_loss: 9.217598351263234e-10
# epoch: 509  train_loss: 9.427116864912932e-10
# epoch: 510  train_loss: 8.844353027726015e-10
# epoch: 511  train_loss: 8.72702021759153e-10
# epoch: 512  train_loss: 7.662113721274011e-10
# epoch: 513  train_loss: 7.283923464385111e-10
# epoch: 514  train_loss: 6.78417877431059e-10
# epoch: 515  train_loss: 6.485720849269683e-10
# epoch: 516  train_loss: 5.857114793172968e-10
# epoch: 517  train_loss: 5.431823324464347e-10
# epoch: 518  train_loss: 4.934246344845405e-10
# epoch: 519  train_loss: 4.4914438834808834e-10
# epoch: 520  train_loss: 4.3906250857261853e-10
# epoch: 521  train_loss: 4.018540777916968e-10
# epoch: 522  train_loss: 3.7728037360906796e-10
# epoch: 523  train_loss: 3.618022548224076e-10
# epoch: 524  train_loss: 3.28658461556941e-10
# epoch: 525  train_loss: 3.0832786324097583e-10
# epoch: 526  train_loss: 2.8594232537315634e-10
# epoch: 527  train_loss: 2.7143920444672176e-10
# epoch: 528  train_loss: 2.544640054225056e-10
# epoch: 529  train_loss: 2.3749935351702334e-10
# epoch: 530  train_loss: 2.2047305647809878e-10
# epoch: 531  train_loss: 2.0457555094388624e-10
# epoch: 532  train_loss: 1.9257515027071292e-10
# epoch: 533  train_loss: 1.8106828536534891e-10
# epoch: 534  train_loss: 1.6822651605075123e-10
# epoch: 535  train_loss: 1.5819082155310582e-10
# epoch: 536  train_loss: 1.4645079593478272e-10
# epoch: 537  train_loss: 1.3884814131781553e-10
# epoch: 538  train_loss: 1.2785006386906161e-10
# epoch: 539  train_loss: 1.235551660982992e-10
# epoch: 540  train_loss: 1.1203689365135716e-10
# epoch: 541  train_loss: 1.0415977802491483e-10
# epoch: 542  train_loss: 9.875493478528341e-11
# epoch: 543  train_loss: 9.499481756769512e-11
# epoch: 544  train_loss: 8.850195576393105e-11
# epoch: 545  train_loss: 8.270627238626815e-11
# epoch: 546  train_loss: 7.599221252263533e-11
# epoch: 547  train_loss: 7.053466144490983e-11
# epoch: 548  train_loss: 6.58497562033844e-11
# epoch: 549  train_loss: 6.338026631302895e-11
# epoch: 550  train_loss: 5.677310704887972e-11
# epoch: 551  train_loss: 5.4801888721423e-11
# epoch: 552  train_loss: 5.098460889585432e-11
# epoch: 553  train_loss: 4.770323719371916e-11
# epoch: 554  train_loss: 4.4125897380453694e-11
# epoch: 555  train_loss: 4.216044874327807e-11
# epoch: 556  train_loss: 3.8014827397070405e-11
# epoch: 557  train_loss: 3.6082546672755456e-11
# epoch: 558  train_loss: 3.330125758482794e-11
# epoch: 559  train_loss: 3.1039257969434075e-11
# epoch: 560  train_loss: 2.8664112750043103e-11
# epoch: 561  train_loss: 2.6478479131508692e-11
# epoch: 562  train_loss: 2.5052663069069503e-11
# epoch: 563  train_loss: 2.3001413274048588e-11
# epoch: 564  train_loss: 2.1515461287591187e-11
# epoch: 565  train_loss: 1.990759466996561e-11
# epoch: 566  train_loss: 1.862768619909083e-11
# epoch: 567  train_loss: 1.7333839225086578e-11
# epoch: 568  train_loss: 1.6370262784226597e-11
# epoch: 569  train_loss: 1.5302901307245875e-11
# epoch: 570  train_loss: 1.4600399014796928e-11
# epoch: 571  train_loss: 1.2762711894265255e-11
# epoch: 572  train_loss: 1.2324648246408998e-11
# epoch: 573  train_loss: 1.1329703668294666e-11
# epoch: 574  train_loss: 1.0951372621248456e-11
# epoch: 575  train_loss: 1.0071172194814348e-11
# epoch: 576  train_loss: 9.6128131496509e-12
# epoch: 577  train_loss: 8.821795724478498e-12
# epoch: 578  train_loss: 8.220781694268098e-12
# epoch: 579  train_loss: 7.872846471967954e-12
# epoch: 580  train_loss: 6.9772495073228136e-12
# epoch: 581  train_loss: 6.553099209105628e-12
# epoch: 582  train_loss: 6.0678927160662255e-12
# epoch: 583  train_loss: 5.639650205169211e-12
# epoch: 584  train_loss: 5.357971444991394e-12
# epoch: 585  train_loss: 5.1596548214516424e-12
# epoch: 586  train_loss: 4.54286044546115e-12
# epoch: 587  train_loss: 4.3049569985187386e-12
# epoch: 588  train_loss: 3.894994569930699e-12
# epoch: 589  train_loss: 3.6598883645933e-12
# epoch: 590  train_loss: 3.441300846715456e-12
# epoch: 591  train_loss: 3.1422724665330914e-12
# epoch: 592  train_loss: 3.0558884415998744e-12
# epoch: 593  train_loss: 2.707735945184364e-12
# epoch: 594  train_loss: 2.461291153527112e-12
# epoch: 595  train_loss: 2.376934586656443e-12
# epoch: 596  train_loss: 2.2136405122136216e-12
# epoch: 597  train_loss: 2.1153283118191535e-12
# epoch: 598  train_loss: 1.9768442525297525e-12
# epoch: 599  train_loss: 1.855438112180474e-12
# epoch: 600  train_loss: 1.6505132763994235e-12
# epoch: 601  train_loss: 1.5096653311133523e-12
# epoch: 602  train_loss: 1.3681653466407484e-12
# epoch: 603  train_loss: 1.3379135039431889e-12
# epoch: 604  train_loss: 1.2937775850652145e-12
# epoch: 605  train_loss: 1.1191152171630137e-12
# epoch: 606  train_loss: 1.0723105346374662e-12
# epoch: 607  train_loss: 1.0314943343914251e-12
# epoch: 608  train_loss: 9.016309834158909e-13
# epoch: 609  train_loss: 8.488349454750799e-13
# epoch: 610  train_loss: 7.873206210248784e-13
# epoch: 611  train_loss: 7.371596822541848e-13
# epoch: 612  train_loss: 6.609338727356362e-13
# epoch: 613  train_loss: 6.086931089374636e-13
# epoch: 614  train_loss: 5.900547520205912e-13
# epoch: 615  train_loss: 5.605407089014081e-13
# epoch: 616  train_loss: 5.177424244537376e-13
# epoch: 617  train_loss: 4.853303089275007e-13
# epoch: 618  train_loss: 4.4405551826755263e-13
# epoch: 619  train_loss: 4.01166730043534e-13
# epoch: 620  train_loss: 3.591716225652408e-13
# epoch: 621  train_loss: 3.50244979503353e-13
# epoch: 622  train_loss: 3.3139669394083304e-13
# epoch: 623  train_loss: 3.0425041284108667e-13
# epoch: 624  train_loss: 2.854016122825348e-13
# epoch: 625  train_loss: 2.772466230118592e-13
# epoch: 626  train_loss: 2.456348655293511e-13
# epoch: 627  train_loss: 2.3010857542332674e-13
# epoch: 628  train_loss: 2.188644637702783e-13
# epoch: 629  train_loss: 2.0544590334514723e-13
# epoch: 630  train_loss: 1.8787795212811542e-13
# epoch: 631  train_loss: 1.7406967523208444e-13
# epoch: 632  train_loss: 1.7036866980114224e-13
# epoch: 633  train_loss: 1.5949432529901997e-13
# epoch: 634  train_loss: 1.4342419938327688e-13
# epoch: 635  train_loss: 1.4660448961582861e-13
# epoch: 636  train_loss: 1.3777686131734301e-13
# epoch: 637  train_loss: 1.314533199089571e-13
# epoch: 638  train_loss: 1.216433773371453e-13
# epoch: 639  train_loss: 1.1379002666338234e-13
# epoch: 640  train_loss: 1.0920366173838847e-13
# epoch: 641  train_loss: 1.0973558487673701e-13
# epoch: 642  train_loss: 9.61367555116395e-14
# epoch: 643  train_loss: 9.289743724705951e-14
# epoch: 644  train_loss: 9.363398999293754e-14
# epoch: 645  train_loss: 8.131729068317634e-14
# epoch: 646  train_loss: 7.674481709851744e-14
# epoch: 647  train_loss: 7.843546775618271e-14
# epoch: 648  train_loss: 7.773080410670291e-14
# epoch: 649  train_loss: 7.275195799526929e-14
# epoch: 650  train_loss: 7.35844287520944e-14
# epoch: 651  train_loss: 6.961565926586616e-14
# epoch: 652  train_loss: 7.57546559119679e-14
# epoch: 653  train_loss: 6.910668733225642e-14
# epoch: 654  train_loss: 6.624799179285462e-14
# epoch: 655  train_loss: 6.333149472513219e-14
# epoch: 656  train_loss: 6.214329045925102e-14
# epoch: 657  train_loss: 5.757231442884286e-14
# epoch: 658  train_loss: 5.322277313963772e-14
# epoch: 659  train_loss: 5.6149583680525916e-14
# epoch: 660  train_loss: 5.4488816345239777e-14
# epoch: 661  train_loss: 5.6518497022241265e-14
# epoch: 662  train_loss: 5.032644562045531e-14
# epoch: 663  train_loss: 5.881173369484682e-14
# epoch: 664  train_loss: 5.1518725808878674e-14
# epoch: 665  train_loss: 5.4004523563581236e-14
# epoch: 666  train_loss: 4.856318391041961e-14
# epoch: 667  train_loss: 4.916677281236945e-14
# epoch: 668  train_loss: 5.0450603709863845e-14
# epoch: 669  train_loss: 4.151091634058829e-14
# epoch: 670  train_loss: 3.8643492973697985e-14
# epoch: 671  train_loss: 3.971556563437881e-14
# epoch: 672  train_loss: 4.5279264278969e-14
# epoch: 673  train_loss: 3.823303097185392e-14
# epoch: 674  train_loss: 3.814759245253027e-14
# epoch: 675  train_loss: 4.2117954360699345e-14
# epoch: 676  train_loss: 4.2437251900496326e-14
# epoch: 677  train_loss: 4.306898940134932e-14
# epoch: 678  train_loss: 4.097562539924146e-14
# epoch: 679  train_loss: 3.667185099424236e-14
# epoch: 680  train_loss: 4.46159087322609e-14
# epoch: 681  train_loss: 4.14906451480946e-14
# epoch: 682  train_loss: 3.982147185783991e-14
# epoch: 683  train_loss: 4.104653222132201e-14
# epoch: 684  train_loss: 3.607535006399515e-14
# epoch: 685  train_loss: 3.50522426839292e-14
# epoch: 686  train_loss: 3.613027168029512e-14
# epoch: 687  train_loss: 3.636623811874122e-14
# epoch: 688  train_loss: 4.0848949927913686e-14
# epoch: 689  train_loss: 3.919720179944991e-14
# epoch: 690  train_loss: 3.867909546253698e-14
# epoch: 691  train_loss: 3.550569669004411e-14
# epoch: 692  train_loss: 3.4375324445669667e-14
# epoch: 693  train_loss: 3.4280531294476543e-14
# epoch: 694  train_loss: 3.236122239863408e-14
# epoch: 695  train_loss: 3.716724329564172e-14
# epoch: 696  train_loss: 3.836781424255281e-14
# epoch: 697  train_loss: 3.692582535314709e-14
# epoch: 698  train_loss: 3.675072670229068e-14
# epoch: 699  train_loss: 3.2699571403480704e-14
# epoch: 700  train_loss: 3.427854923737997e-14
# epoch: 701  train_loss: 3.303497950993446e-14
# epoch: 702  train_loss: 3.406522568367987e-14
# epoch: 703  train_loss: 3.3224650515615434e-14
# epoch: 704  train_loss: 3.24768085146164e-14
# epoch: 705  train_loss: 3.7187473830553944e-14
# epoch: 706  train_loss: 3.1700638343729395e-14
# epoch: 707  train_loss: 3.3948436780912444e-14
# epoch: 708  train_loss: 3.23986985243524e-14
# epoch: 709  train_loss: 4.216206106032877e-14
# epoch: 710  train_loss: 4.10203453507247e-14
# epoch: 711  train_loss: 4.1956963890612403e-14
# epoch: 712  train_loss: 4.088695460219109e-14
# epoch: 713  train_loss: 4.129309334787237e-14
# epoch: 714  train_loss: 3.7623055441481784e-14
# epoch: 715  train_loss: 3.820961559306002e-14
# epoch: 716  train_loss: 4.109825544121315e-14
# epoch: 717  train_loss: 3.984931552488205e-14
# epoch: 718  train_loss: 3.665354830631809e-14
# epoch: 719  train_loss: 3.7089075707137306e-14
# epoch: 720  train_loss: 3.3682702216568036e-14
# epoch: 721  train_loss: 4.142811039966471e-14
# epoch: 722  train_loss: 4.124007924976962e-14
# epoch: 723  train_loss: 3.7846062275834896e-14
# epoch: 724  train_loss: 3.9286777227687947e-14
# epoch: 725  train_loss: 4.404301630431956e-14
# epoch: 726  train_loss: 3.7946174793936777e-14
# epoch: 727  train_loss: 3.914559038790781e-14
# epoch: 728  train_loss: 4.063035782928166e-14
# epoch: 729  train_loss: 4.4498266020282645e-14
# epoch: 730  train_loss: 4.030037073369033e-14
# epoch: 731  train_loss: 4.543929251962786e-14
# epoch: 732  train_loss: 5.060920215890774e-14
# epoch: 733  train_loss: 5.510983379711232e-14
# epoch: 734  train_loss: 4.851025790374337e-14
# epoch: 735  train_loss: 6.015015417172587e-14
# epoch: 736  train_loss: 5.6701246074677275e-14
# epoch: 737  train_loss: 6.013216319192619e-14
# epoch: 738  train_loss: 6.011159723196685e-14
# epoch: 739  train_loss: 7.599649398280436e-14
# epoch: 740  train_loss: 5.504443607732071e-14
# epoch: 741  train_loss: 4.653154489324407e-14
# epoch: 742  train_loss: 4.0943383937137173e-14
# epoch: 743  train_loss: 3.807430716193383e-14
# epoch: 744  train_loss: 4.029758230122797e-14
# epoch: 745  train_loss: 3.612223503169157e-14
# epoch: 746  train_loss: 3.8028574159045675e-14
# epoch: 747  train_loss: 3.569815612818744e-14
# epoch: 748  train_loss: 3.928573368309693e-14
# epoch: 749  train_loss: 3.170596109876994e-14
# epoch: 750  train_loss: 3.4417669316768804e-14
# epoch: 751  train_loss: 3.124490412492048e-14
# epoch: 752  train_loss: 3.593654508086269e-14
# epoch: 753  train_loss: 3.9365937538806545e-14
# epoch: 754  train_loss: 3.4705833313556506e-14
# epoch: 755  train_loss: 4.167232016275349e-14
# epoch: 756  train_loss: 3.8734820066070944e-14
# epoch: 757  train_loss: 3.9639529180769684e-14
# epoch: 758  train_loss: 3.85534703120638e-14
# epoch: 759  train_loss: 3.462838400899136e-14
# epoch: 760  train_loss: 3.620463439680047e-14
# epoch: 761  train_loss: 4.117975356326617e-14
# epoch: 762  train_loss: 3.824258211536716e-14
# epoch: 763  train_loss: 4.0081307684739637e-14
# epoch: 764  train_loss: 4.267375705189688e-14
# epoch: 765  train_loss: 3.520341095995978e-14
# epoch: 766  train_loss: 3.7320888296010074e-14
# epoch: 767  train_loss: 3.645953032755181e-14
# epoch: 768  train_loss: 3.693031123963575e-14
# epoch: 769  train_loss: 3.285623861740486e-14
# epoch: 770  train_loss: 3.484736574277912e-14
# epoch: 771  train_loss: 4.0104990725944867e-14
# epoch: 772  train_loss: 4.007884112479723e-14
# epoch: 773  train_loss: 3.7671146584095094e-14
# epoch: 774  train_loss: 3.6928427438361056e-14
# epoch: 775  train_loss: 4.8090251534649645e-14
# epoch: 776  train_loss: 3.3075820050519275e-14
# epoch: 777  train_loss: 3.446430017458105e-14
# epoch: 778  train_loss: 3.3862689941596e-14
# epoch: 779  train_loss: 3.7972033015750556e-14
# epoch: 780  train_loss: 3.935424170787086e-14
# epoch: 781  train_loss: 3.506396900805099e-14
# epoch: 782  train_loss: 3.780137281753776e-14
# epoch: 783  train_loss: 3.6678244398928236e-14
# epoch: 784  train_loss: 3.7779183942451486e-14
# epoch: 785  train_loss: 4.8833177356422813e-14
# epoch: 786  train_loss: 3.6089634427617645e-14
# epoch: 787  train_loss: 3.745141268505017e-14
# epoch: 788  train_loss: 3.3652087057722477e-14
# epoch: 789  train_loss: 3.471778664250816e-14
# epoch: 790  train_loss: 3.4235784237938993e-14
# epoch: 791  train_loss: 3.795143995073691e-14
# epoch: 792  train_loss: 3.9703097309395224e-14
# epoch: 793  train_loss: 4.387277962258039e-14
# epoch: 794  train_loss: 4.884826131914752e-14
# epoch: 795  train_loss: 4.474373955652873e-14
# epoch: 796  train_loss: 4.019150328304563e-14
# epoch: 797  train_loss: 3.8734884440574935e-14
# epoch: 798  train_loss: 3.7932114047012355e-14
# epoch: 799  train_loss: 3.675776046388468e-14
# epoch: 800  train_loss: 3.9475045546808266e-14
# epoch: 801  train_loss: 3.7220250617480896e-14
# epoch: 802  train_loss: 3.704606676220752e-14
# epoch: 803  train_loss: 3.342530923268819e-14
# epoch: 804  train_loss: 3.110577049300449e-14
# epoch: 805  train_loss: 3.9611536435928824e-14
# epoch: 806  train_loss: 4.0329630639820285e-14
# epoch: 807  train_loss: 3.9581026309168724e-14
# epoch: 808  train_loss: 5.064101671640661e-14
# epoch: 809  train_loss: 6.430300085805141e-14
# epoch: 810  train_loss: 5.245345038309632e-14
# epoch: 811  train_loss: 6.773546296339611e-14
# epoch: 812  train_loss: 8.02401019434941e-14
# epoch: 813  train_loss: 6.875661877955158e-14
# epoch: 814  train_loss: 5.1652692539816414e-14
# epoch: 815  train_loss: 4.653003378646617e-14
# epoch: 816  train_loss: 4.260856939627619e-14
# epoch: 817  train_loss: 4.787962832198539e-14
# epoch: 818  train_loss: 4.3497378008489074e-14
# epoch: 819  train_loss: 5.0517444773797576e-14
# epoch: 820  train_loss: 4.754115395626257e-14
# epoch: 821  train_loss: 5.460554087350321e-14
# epoch: 822  train_loss: 4.6025276688801964e-14
# epoch: 823  train_loss: 4.4958428527339805e-14
# epoch: 824  train_loss: 4.316530043558392e-14
# epoch: 825  train_loss: 4.4583870558063954e-14
# epoch: 826  train_loss: 4.006292029352064e-14
# epoch: 827  train_loss: 4.1803308725848684e-14
# epoch: 828  train_loss: 4.40875194153683e-14
# epoch: 829  train_loss: 4.625527662716761e-14
# epoch: 830  train_loss: 4.49445473514002e-14
# epoch: 831  train_loss: 4.195125150041612e-14
# epoch: 832  train_loss: 4.563465219858259e-14
# epoch: 833  train_loss: 4.735758836406541e-14
# epoch: 834  train_loss: 4.5692531653934373e-14
# epoch: 835  train_loss: 4.4908789008498914e-14
# epoch: 836  train_loss: 4.2950167619508484e-14
# epoch: 837  train_loss: 3.765629979059562e-14
# epoch: 838  train_loss: 5.455795456252646e-14
# epoch: 839  train_loss: 4.2474206253919136e-14
# epoch: 840  train_loss: 3.906186626326941e-14
# epoch: 841  train_loss: 3.892346785595163e-14
# epoch: 842  train_loss: 3.6513320307834246e-14
# epoch: 843  train_loss: 4.606230558112413e-14
# epoch: 844  train_loss: 3.651619344359133e-14
# epoch: 845  train_loss: 3.8322155778564015e-14
# epoch: 846  train_loss: 3.520932324993162e-14
# Early stopping!!!
# <All keys matched successfully>

# %% [markdown]
# ## Parameter estimation results
#
# Remember that the true dynamics of our system can be represented by:
# $$
#  \frac{dx}{dt} = sin(y) - b x
# $$
# $$
#  \frac{dy}{dt} = sin(z) - b y
# $$
# $$
#  \frac{dz}{dt} = sin(x) - b z
# $$
#
# Here, we can see that the model correctly identified a sparse linear combination of terms from our function library, and accurately estimated the value of the parameter $b$.

# %%
print(fx)
print(f"True value of b: {modelSystem.b}")
# Out:
# dx0/dt = 1.000*sin(1*x1) + -0.208*x0
# dx1/dt = 1.000*sin(1*x2) + -0.208*x1
# dx2/dt = 1.000*sin(1*x0) + -0.208*x2
#
# True value of b: 0.20818600058555603

# %% [markdown]
# ## Test Results
# The plot below shows that given some initial condition, the model can accurately predict the trajectory of our state variables.

# %%
# update the rollout length based on the test data
dynamics_model.nsteps = test_data['X'].shape[1]

# %%
# Test set results
test_outputs = dynamics_model(test_data)

pred_traj = test_outputs['xn'][:, :-1, :]
true_traj = test_data['X']
pred_traj = pred_traj.detach().numpy().reshape(-1, nx)
true_traj = true_traj.detach().numpy().reshape(-1, nx)
pred_traj, true_traj = pred_traj.transpose(1, 0), true_traj.transpose(1, 0)

# %%
# plot rollout
figsize = 25
fig, ax = plt.subplots(nx, figsize=(figsize, figsize))
labels = [f'$y_{k}$' for k in range(len(true_traj))]
for row, (t1, t2, label) in enumerate(zip(true_traj, pred_traj, labels)):
    if nx > 1:
        axe = ax[row]
    else:
        axe = ax
    axe.set_ylabel(label, rotation=0, labelpad=20, fontsize=figsize)
    axe.plot(t1, 'c', linewidth=4.0, label='True')
    axe.plot(t2, 'm--', linewidth=4.0, label='Pred')
    axe.tick_params(labelbottom=False, labelsize=figsize)
axe.tick_params(labelbottom=True, labelsize=figsize)
axe.legend(fontsize=figsize)
axe.set_xlabel('$time$', fontsize=figsize)
plt.tight_layout()
